# %%
def currency_1():
    """name of graph"""
    
    crypto_currency1 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_1 = crypto_currency1.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_1.set_ylim(370000, 387500)
    return crypto_1

def currency_2():
    """name of graph"""
    
    crypto_currency2 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_2 = crypto_currency2.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_2.set_ylim(370000, 387500)
    return crypto_2

def currency_3():
    """name of graph"""
    
    crypto_currency3 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_3 = crypto_currency3.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_3.set_ylim(370000, 387500)
    return crypto_3

def currency_4():
    """name of graph"""
    
    crypto_currency4 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_4 = crypto_currency4.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_4.set_ylim(370000, 387500)
    return crypto_4

def currency_5():
    """name of graph"""
    
    crypto_currency5 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_5 = crypto_currency5.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_5.set_ylim(370000, 387500)
    return crypto_5

def currency_6():
    """name of graph"""

    crypto_currency6 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_6 = crypto_currency6.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_6.set_ylim(370000, 387500)
    return crypto_6

def currency_7():
    """name of graph"""
    
    crypto_currency7 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_7 = crypto_currency7.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_7.set_ylim(370000, 387500)
    return crypto_7

def currency_8():
    """name of graph"""
    
    crypto_currency8 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_8 = crypto_currency8.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_8.set_ylim(370000, 387500)
    return crypto_8

def currency_9():
    """name of graph"""
    
    crypto_currency9 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_9 = crypto_currency9.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_9.set_ylim(370000, 387500)
    return crypto_9

def currency_10():
    """name of graph"""
    
    crypto_currency10 = csv_file["___"].groupby([csv_file.index]).mean()
    crypto_10 = crypto_currency10.plot.bar(x="___", y="___", 
    title="Name of Graph X-XX-XXXX",
    ) 
    crypto_10.set_ylim(370000, 387500)
    return crypto_10


###


# Create a Title for the Dashboard
# YOUR CODE HERE!
Info = pn.pane.Markdown(
""""
    
    Crypto Data ,
    1- Your Portfolio,
    2- Live Crypto Prices,
    3- Futures and Forecasts,
    4- About
   """
)


tab_1 = pn.Column(
    ("#Your Portfolio"),
    ("#Holdings and Positions"),
    personal_crypto_data1,
    personal_crypto_data2
)

tab_2 = pn.Column(
    ("#Live Market Watch"),
    ("#Current Top Ten Currencies (CoinGecko)"),
    
    #Top 10
    crypto_currency1,
    crypto_currency2,
    crypto_currency3,
    crypto_currency4,
    crypto_currency5,
    crypto_currency6,
    crypto_currency7,
    crypto_currency8,
    crypto_currency9,
    crypto_currency10
    
    ("#Top 10 Most Expensive Neighborhoods"),
    top_most_expensive_neighborhoods
)


tab_3 = pn.Column(
    ("#Futures and Forecasts"),
    line_plot = MC_1_year.plot_simulation()
)

tab_4 = pn.Column(
    ("#About")
print("This was a project by Joey Dima, Juan Raigosa, Francis Ocran IV, and Thomas Guyton. 2022")
)


# Create the dashboard
# YOUR CODE HERE!
panel = pn.Tabs(
    ("Crypto Data",Info),
    ("Your Portfolio", tab_1),
    ("Live Crypto Prices", tab_2),
    ("Futures and Forecasts", tab_3),
    ("About", tab_4)
    
)

###
